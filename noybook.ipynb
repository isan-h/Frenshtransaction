# %%
import pandas as pd

df = pd.read_csv("data/processed/cleaned_transactions.csv")

print(df["merchant"].value_counts().sort_values().head(30))
# Out:
# merchant
# Spar                     1
# Marche U                 1
# Molotov                  1
# Canva                    1
# Monoprix                 1
# Casino                   1
# Buffalo Grill            2
# Carrefour                2
# Station E.Leclerc        2
# Picard                   2
# Speed Rabbit Pizza       2
# Printemps                2
# Ikea                     2
# Dab Hsbc                 2
# E.Leclerc                2
# Intermarche              2
# Pathe Cinema             2
# Brasserie Le Comptoir    3
# Keep Cool                3
# Dab Societe Generale     3
# Dab Credit Mutuel        3
# Ugc                      3
# Vinted                   3
# Carrefour Market         3
# Pharma Gdd               3
# La Vie Claire            3
# Cora                     3
# Pokawa                   3
# Quick                    3
# Disney Plus              3
# Name: count, dtype: int64
